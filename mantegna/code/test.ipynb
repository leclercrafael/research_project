# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('../../csv/kg_companies_2004-01-01_2024-01-01.csv')
data.head()
# Out:
#          Date         AA  AAL      AAPL  ABBV  ABNB        ABT  ACI  \
# 0  2004-01-02  69.188026  NaN  0.319105   NaN   NaN  11.707191  NaN
# 1  2004-01-05  71.454384  NaN  0.332451   NaN   NaN  11.707191  NaN
# 2  2004-01-06  70.920036  NaN  0.331251   NaN   NaN  11.622050  NaN
# 3  2004-01-07  70.385681  NaN  0.338749   NaN   NaN  11.744756  NaN
# 4  2004-01-08  71.233246  NaN  0.350295   NaN   NaN  11.399175  NaN
#
#         ADBE  ADDYY  ...        XOM  XPEV       XPO        XRX  YAHOY  YELP  \
# 0  19.518396    NaN  ...  19.699320   NaN  1.812275  16.029545    NaN   NaN
# 1  19.867834    NaN  ...  20.159924   NaN  1.812275  16.300827    NaN   NaN
# 2  19.887802    NaN  ...  20.024166   NaN  1.867611  16.595701    NaN   NaN
# 3  19.694551    NaN  ...  19.878712   NaN  2.075124  16.654682    NaN   NaN
# 4  18.975479    NaN  ...  19.830231   NaN  2.863671  16.701864    NaN   NaN
#
#    YMM  YUMC   Z  ZM
# 0  NaN   NaN NaN NaN
# 1  NaN   NaN NaN NaN
# 2  NaN   NaN NaN NaN
# ...

# %%
(data==None).value_counts().value_counts()
# Out:
# count
# 5033    1
# Name: count, dtype: int64

# %%
log_returns=pd.read_csv('log_returns_sp500_2004-01-01_2024-01-01.csv')
log_returns.shape
# Out:
# (5032, 498)

# %%
print(data.iloc[3,2])
print(log_returns.iloc[3,2])
# Out:
# 0.3387489914894104
# 0.0335176434653112

# %%
data.columns.to_list()
# Out:
# ['Date',
#  'A',
#  'AAPL',
#  'ABBV',
#  'ABNB',
#  'ABT',
#  'ACGL',
#  'ACN',
#  'ADBE',
#  'ADI',
#  'ADM',
#  'ADP',
#  'ADSK',
#  'AEE',
#  'AEP',
#  'AES',
#  'AFL',
#  'AIG',
#  'AIZ',
#  'AJG',
#  'AKAM',
#  'ALB',
#  'ALGN',
#  'ALL',
#  'ALLE',
#  'AMAT',
#  'AMCR',
#  'AMD',
#  'AME',
#  'AMGN',
#  'AMP',
#  'AMT',
#  'AMZN',
#  'ANET',
#  'AON',
#  'AOS',
#  'APA',
#  'APD',
#  'APH',
#  'APO',
#  'APP',
#  'APTV',
#  'ARE',
#  'ARES',
#  'ATO',
#  'AVB',
#  'AVGO',
#  'AVY',
#  'AWK',
#  'AXON',
#  'AXP',
#  'AZO',
#  'BA',
#  'BAC',
#  'BALL',
#  'BAX',
#  'BBY',
#  'BDX',
#  'BEN',
#  'BG',
#  'BIIB',
#  'BK',
#  'BKNG',
#  'BKR',
#  'BLDR',
#  'BLK',
#  'BMY',
#  'BR',
#  'BRO',
#  'BSX',
#  'BX',
#  'BXP',
#  'C',
#  'CAG',
#  'CAH',
#  'CARR',
#  'CAT',
#  'CB',
#  'CBOE',
#  'CBRE',
#  'CCI',
#  'CCL',
#  'CDNS',
#  'CDW',
#  'CEG',
#  'CF',
#  'CFG',
#  'CHD',
#  'CHRW',
#  'CHTR',
#  'CI',
#  'CINF',
#  'CL',
#  'CLX',
#  'CMCSA',
#  'CME',
#  'CMG',
#  'CMI',
# ...
